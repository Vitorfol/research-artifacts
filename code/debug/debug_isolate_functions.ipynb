# %%
import sys
import os

# Adiciona os diretórios necessários ao caminho de pesquisa do Python
sys.path.append(os.path.abspath(os.path.join('..', 'src', 'data_processing')))
sys.path.append(os.path.abspath(os.path.join('..', 'src', 'plot_navigator')))

# Agora os imports devem funcionar
from csvReader import load_csv_as_df
from trateData import convert_comma_and_percent_columns, find_correlations, convert_df_columns_to_float

# %%
file = 'C:/Users/necta/Downloads/robo.csv'
robo_df = load_csv_as_df(file)
robo_df.head(len(robo_df))
# Out:
# Arquivo C:/Users/necta/Downloads/robo.csv carregado com sucesso!
#                               Link Semestre  N do projeto  God Class  \
# 0                         JogoRobo     24,2             2          0
# 1                    JavaRobotUece     24,2             2          2
# 2                             Pato     24,2             2          2
# 3                       POO---ROBO     24,2             2          0
# 4                        npc2-robo     24,2             2          0
# 5   Trabalho Tratamento de Excecao     24,2             2          0
# 6            Tratamento-de-Exce--o     24,2             2          0
# 7                     trabalhorobo     24,2             1          2
# 8                  Robozinhos_Java     24,2             2          1
# 9                          RoboPoo     24,2             2          2
# 10                Trabalho2-de-POO     24,1             2          2
# 11                    TrabalhoPOO2     24,1             2          2
#
# ...

# %%
robo_df = convert_comma_and_percent_columns(robo_df)
robo_df.head(len(robo_df))
# Out:
#                               Link Semestre  N do projeto  God Class  \
# 0                         JogoRobo     24.2             2          0
# 1                    JavaRobotUece     24.2             2          2
# 2                             Pato     24.2             2          2
# 3                       POO---ROBO     24.2             2          0
# 4                        npc2-robo     24.2             2          0
# 5   Trabalho Tratamento de Excecao     24.2             2          0
# 6            Tratamento-de-Exce--o     24.2             2          0
# 7                     trabalhorobo     24.2             1          2
# 8                  Robozinhos_Java     24.2             2          1
# 9                          RoboPoo     24.2             2          2
# 10                Trabalho2-de-POO     24.1             2          2
# 11                    TrabalhoPOO2     24.1             2          2
#
#     Type checking  Long Method  Feature Envy  N code smells  \
# ...

# %%
find_correlations(robo_df)
# Out:
# {1: ('God Class',
#   'Intencionalidade',
#   np.float64(0.7170834875636828),
#   'direta'),
#  2: ('Long Method', 'N code smells', np.float64(0.9690294856076016), 'direta'),
#  3: ('Long Method', 'Smells / LOC', np.float64(0.9356656081747559), 'direta'),
#  4: ('Long Method', 'Classes', np.float64(0.750526598576868), 'direta'),
#  5: ('Feature Envy',
#   'Reliability Issues / R',
#   np.float64(0.747038020449487),
#   'direta'),
#  6: ('N code smells', 'Smells / LOC', np.float64(0.886400837914512), 'direta'),
#  7: ('N code smells', 'Classes', np.float64(0.7965001136173466), 'direta'),
#  8: ('Reliability Issues / R',
#   'Security Hotspots / R',
#   np.float64(0.9108565954885547),
#   'direta'),
#  9: ('Reliability Issues / R',
#   'Funções',
#   np.float64(0.8060659379383421),
#   'direta'),
#  10: ('Debt Ratio / R',
#   'Open Issue / LOC',
#   np.float64(0.943345904005543),
#   'direta'),
#  11: ('Debt Ratio / R',
#   'Adaptabilidade',
#   np.float64(0.7592218640644016),
# ...

# %%
convert_df_columns_to_float(robo_df)
robo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Link                    12 non-null     object
#  1   Semestre                12 non-null     object
#  2   N do projeto            12 non-null     int64
#  3   God Class               12 non-null     int64
#  4   Type checking           12 non-null     int64
#  5   Long Method             12 non-null     int64
#  6   Feature Envy            12 non-null     int64
#  7   N code smells           12 non-null     int64
#  8   Reliability Issues / R  12 non-null     int64
#  9   Debt Ratio / R          12 non-null     float64
#  10  Security Hotspots / R   12 non-null     int64
#  11  Density Duplication     12 non-null     float64
#  12  LOC                     12 non-null     int64
#  13  Cyclomatic Complexity   12 non-null     int64
# ...
