# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..', 'src', 'services')))
sys.path.append(os.path.abspath(os.path.join('..', 'src', 'data_processing')))

from processData import process_csv_path
from showCorrelation import show_correlation
from dataInsights import show_median_comparator, show_kurtosis_and_skewness, df_describe_and_info

# %%
original_robo = 'C:/Users/necta/Downloads/robo.csv'
original_tabuleiro = 'C:/Users/necta/Downloads/tabuleiro.csv'
final_robo = process_csv_path(original_robo)
final_tabuleiro = process_csv_path(original_tabuleiro)
# Out:
# Arquivo C:/Users/necta/Downloads/robo.csv carregado com sucesso!
# Arquivo C:/Users/necta/Downloads/tabuleiro.csv carregado com sucesso!

# %%
show_correlation(final_tabuleiro)
# Out:
# 1: Long Method e N code smells têm uma correlação direta de 0.99
# 2: Long Method e Smells / LOC têm uma correlação direta de 0.84
# 3: N code smells e Smells / LOC têm uma correlação direta de 0.83
# 4: Debt Ratio / R e Cognitive Complexity têm uma correlação direta de 0.79
# 5: Debt Ratio / R e Open Issue / LOC têm uma correlação direta de 0.80
# 6: Security Hotspots / R e Smells / LOC têm uma correlação inversa de -0.74
# 7: LOC e Cyclomatic Complexity têm uma correlação direta de 0.97
# 8: LOC e Open Issues têm uma correlação direta de 0.82
# 9: LOC e Classes têm uma correlação direta de 0.72
# 10: LOC e SI Medium têm uma correlação direta de 0.77
# 11: LOC e Intencionalidade têm uma correlação direta de 0.77
# 12: LOC e Adaptabilidade têm uma correlação direta de 0.72
# 13: Cyclomatic Complexity e Open Issues têm uma correlação direta de 0.78
# 14: Cyclomatic Complexity e SI Medium têm uma correlação direta de 0.71
# ...

# %%
show_median_comparator(final_robo, final_tabuleiro)
# Out:
# Medians of df1 higher than medians of df2:
#                          series1  series2  difference
# LOC                     600.5000  334.000    266.5000
# Cognitive Complexity    151.0000   75.500     75.5000
# Cyclomatic Complexity   131.5000   79.500     52.0000
# Open Issues              94.5000   57.500     37.0000
# Adaptabilidade           73.5000   40.500     33.0000
# SI Medium                68.0000   40.500     27.5000
# SI Low                   23.0000   14.000      9.0000
# Consistência             11.5000    3.500      8.0000
# Funções                  36.5000   30.500      6.0000
# Long Method              14.0000    9.500      4.5000
# N code smells            15.5000   11.500      4.0000
# Classes                  11.0000    7.000      4.0000
# God Class                 1.5000    0.000      1.5000
# SI High                   8.5000    7.000      1.5000
# Reliability Issues / R    2.0000    1.500      0.5000
# Security Hotspots / R     4.0000    3.500      0.5000
# ...

# %%
show_kurtosis_and_skewness(final_robo)
# Out:
# Kurtosis:
# Feature Envy              8.975806
# Adaptabilidade            5.471433
# SI Medium                 5.093391
# Open Issues               4.741530
# Cognitive Complexity      3.832082
# Open Issue / LOC          3.360886
# LOC                       2.369427
# Debt Ratio / R            2.270810
# Reliability Issues / R    2.268504
# SI High                   1.497071
# Type checking             1.387877
# Classes                   1.157538
# Cyclomatic Complexity     1.039971
# Intencionalidade         -0.262759
# Density Duplication      -0.594699
# Funções                  -0.646290
# Security Hotspots / R    -0.681750
# N code smells            -0.991419
# Long Method              -1.117229
# Smells / LOC             -1.266010
# Consistência             -1.291086
# SI Low                   -1.582521
# God Class                -2.253715
# dtype: float64
#
# Skewness:
# Feature Envy              2.911755
# SI Medium                 1.715835
# ...

# %%
df_describe_and_info(final_robo)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Link                    12 non-null     object
#  1   Semestre                12 non-null     object
#  2   N do projeto            12 non-null     int64
#  3   God Class               12 non-null     int64
#  4   Type checking           12 non-null     int64
#  5   Long Method             12 non-null     int64
#  6   Feature Envy            12 non-null     int64
#  7   N code smells           12 non-null     int64
#  8   Reliability Issues / R  12 non-null     int64
#  9   Debt Ratio / R          12 non-null     float64
#  10  Security Hotspots / R   12 non-null     int64
#  11  Density Duplication     12 non-null     float64
#  12  LOC                     12 non-null     int64
#  13  Cyclomatic Complexity   12 non-null     int64
# ...
